# %%
#encoding=utf-8
import json
hash = {}
for item in seglist: 
    if item in hash:
      hash[item] += 1
    else:
      hash[item] = 1
fd = open("count.csv","w")
fd.write("word,count\n")
for k in hash:
  fd.write("%s,%d\n"%(k.encode("utf8"),hash[k]))

# %%
#encoding=utf-8
import jieba

sentence = "里約奧運男子200公尺蝶式，美國「飛魚」菲爾普斯（Michael Phelps）以1分53秒36的成績獲勝，奪下奧運生涯第20金，同時締造許多難以超越的「飛魚障礙」。據ESPN顯示，現年31歲的菲爾普斯，是奧運游泳史上最老的個人金牌得主。"
print "Input：", sentence
words = jieba.cut(sentence, cut_all=False)
print "Output 精確模式 Full Mode："
for word in words:
    print word

sentence = "里約奧運男子200公尺蝶式，美國「飛魚」菲爾普斯（Michael Phelps）以1分53秒36的成績獲勝，奪下奧運生涯第20金，同時締造許多難以超越的「飛魚障礙」。據ESPN顯示，現年31歲的菲爾普斯，是奧運游泳史上最老的個人金牌得主。"
print "Input：", sentence
words = jieba.cut(sentence, cut_all=False)
print "Output 精確模式 Full Mode："
for word in words:
    print word
# Out:
# Input： 里約奧運男子200公尺蝶式，美國「飛魚」菲爾普斯（Michael Phelps）以1分53秒36的成績獲勝，奪下奧運生涯第20金，同時締造許多難以超越的「飛魚障礙」。據ESPN顯示，現年31歲的菲爾普斯，是奧運游泳史上最老的個人金牌得主。
# Output 精確模式 Full Mode：
# 里
# 約
# 奧運
# 男子
# 200
# 公尺
# 蝶式
# ，
# 美國
# 「
# 飛魚
# 」
# 菲爾普斯
# （
# Michael
#
# Phelps
# ）
# 以
# 1
# 分
# 53
# 秒
# 36
# 的
# 成績
# 獲勝
# ，
# 奪下
# 奧運
# 生涯
# 第
# 20
# 金
# ，
# 同時
# 締造
# 許多
# 難以
# 超越
# 的
# 「
# 飛魚
# 障礙
# 」
# 。
# 據
# ESPN
# 顯示
# ，
# 現年
# 31
# 歲
# 的
# 菲爾普斯
# ，
# 是
# 奧運
# 游泳
# 史上
# 最
# 老
# 的
# 個
# 人
# 金牌得主
# 。
# Input： 里約奧運男子200公尺蝶式，美國「飛魚」菲爾普斯（Michael Phelps）以1分53秒36的成績獲勝，奪下奧運生涯第20金，同時締造許多難以超越的「飛魚障礙」。據ESPN顯示，現年31歲的菲爾普斯，是奧運游泳史上最老的個人金牌得主。
# Output 精確模式 Full Mode：
# 里
# 約
# 奧運
# 男子
# 200
# 公尺
# 蝶式
# ，
# 美國
# 「
# 飛魚
# 」
# 菲爾普斯
# （
# Michael
#
# Phelps
# ）
# 以
# 1
# 分
# 53
# 秒
# 36
# 的
# 成績
# 獲勝
# ，
# 奪下
# 奧運
# 生涯
# 第
# 20
# 金
# ，
# 同時
# 締造
# 許多
# 難以
# 超越
# 的
# 「
# 飛魚
# 障礙
# 」
# 。
# 據
# ESPN
# 顯示
# ，
# 現年
# 31
# 歲
# 的
# 菲爾普斯
# ，
# 是
# 奧運
# 游泳
# 史上
# 最
# 老
# 的
# 個
# 人
# 金牌得主
# 。

# %%
#encoding=utf-8
#讀檔做斷詞
import jieba

content = open('test.txt', 'rb').read()

print "Input：", content

words = jieba.cut(content, cut_all=False)

print "Output 精確模式 Full Mode："
for word in words:
    print word
# Out:
# Input： 里約奧運男子200公尺蝶式，美國「飛魚」菲爾普斯（Michael Phelps）以1分53秒36的成績獲勝，奪下奧運生涯第20金，同時締造許多難以超越的「飛魚障礙」。據ESPN顯示，現年31歲的菲爾普斯，是奧運游泳史上最老的個人金牌得主。
#
# Output 精確模式 Full Mode：
# 里
# 約
# 奧運
# 男子
# 200
# 公尺
# 蝶式
# ，
# 美國
# 「
# 飛魚
# 」
# 菲爾普斯
# （
# Michael
#
# Phelps
# ）
# 以
# 1
# 分
# 53
# 秒
# 36
# 的
# 成績
# 獲勝
# ，
# 奪下
# 奧運
# 生涯
# 第
# 20
# 金
# ，
# 同時
# 締造
# 許多
# 難以
# 超越
# 的
# 「
# 飛魚
# 障礙
# 」
# 。
# 據
# ESPN
# 顯示
# ，
# 現年
# 31
# 歲
# 的
# 菲爾普斯
# ，
# 是
# 奧運
# 游泳
# 史上
# 最
# 老
# 的
# 個
# 人
# 金牌得主
# 。

# %%
#encoding=utf-8
#取出文章中的關鍵詞
import jieba
import jieba.analyse

#jieba.set_dictionary('dict.txt.big')

content = open('test.txt', 'rb').read()

print "Input：", content

tags = jieba.analyse.extract_tags(content, 100)

print "Output："
print ",".join(tags)
# Out:
# Input： 里約奧運男子200公尺蝶式，美國「飛魚」菲爾普斯（Michael Phelps）以1分53秒36的成績獲勝，奪下奧運生涯第20金，同時締造許多難以超越的「飛魚障礙」。據ESPN顯示，現年31歲的菲爾普斯，是奧運游泳史上最老的個人金牌得主。
#
# Output：
# 奧運,菲爾普斯,飛魚,金牌得主,蝶式,締造,ESPN,獲勝,成績,難以,美國,20,Phelps,顯示,200,許多,現年,奪下,Michael,障礙,同時,31,36,53,公尺,生涯,游泳,史上,超越,男子

# %%
import jieba
import json

content = open('test.txt', 'rb').read()

print "Input：", content


words = jieba.cut(content, cut_all=False)

print "Output 精確模式 Full Mode："
for word in words:
    print word
    fd = open("count.txt","a")
    fd.write(word.encode('utf8'))
    fd.write('\n')
    
fd.close()

hash = {}
#for item in words: 
#    if item in hash:
#      hash[item] += 1
#    else:
#      hash[item] = 1
#json.dump(hash,open("count.json","w"))

#fd = open("count.txt","w")
#for k in hash:
#  fd.write("%s\n"%(k.encode("utf8")))

#fd.close()
# Out:
# Input： 里約奧運男子200公尺蝶式，美國「飛魚」菲爾普斯（Michael Phelps）以1分53秒36的成績獲勝，奪下奧運生涯第20金，同時締造許多難以超越的「飛魚障礙」。據ESPN顯示，現年31歲的菲爾普斯，是奧運游泳史上最老的個人金牌得主。
#
# Output 精確模式 Full Mode：
# 里
# 約
# 奧運
# 男子
# 200
# 公尺
# 蝶式
# ，
# 美國
# 「
# 飛魚
# 」
# 菲爾普斯
# （
# Michael
#
# Phelps
# ）
# 以
# 1
# 分
# 53
# 秒
# 36
# 的
# 成績
# 獲勝
# ，
# 奪下
# 奧運
# 生涯
# 第
# 20
# 金
# ，
# 同時
# 締造
# 許多
# 難以
# 超越
# 的
# 「
# 飛魚
# 障礙
# 」
# 。
# 據
# ESPN
# 顯示
# ，
# 現年
# 31
# 歲
# 的
# 菲爾普斯
# ，
# 是
# 奧運
# 游泳
# 史上
# 最
# 老
# 的
# 個
# 人
# 金牌得主
# 。

# %%
#encoding=utf-8
#讀檔做斷詞
import jieba
import re

content = open('test.txt', 'rb').read()
r='[’!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]+「」，。'
line=re.sub(r,'',content)


print "Input：", line

words = jieba.cut(line, cut_all=False)

print "Output 精確模式 Full Mode："
for word in words:
    print word
# Out:
# Input： 里約奧運男子200公尺蝶式，美國「飛魚」菲爾普斯（Michael Phelps）以1分53秒36的成績獲勝，奪下奧運生涯第20金，同時締造許多難以超越的「飛魚障礙」。據ESPN顯示，現年31歲的菲爾普斯，是奧運游泳史上最老的個人金牌得主。
#
# Output 精確模式 Full Mode：
# 里
# 約
# 奧運
# 男子
# 200
# 公尺
# 蝶式
# ，
# 美國
# 「
# 飛魚
# 」
# 菲爾普斯
# （
# Michael
#
# Phelps
# ）
# 以
# 1
# 分
# 53
# 秒
# 36
# 的
# 成績
# 獲勝
# ，
# 奪下
# 奧運
# 生涯
# 第
# 20
# 金
# ，
# 同時
# 締造
# 許多
# 難以
# 超越
# 的
# 「
# 飛魚
# 障礙
# 」
# 。
# 據
# ESPN
# 顯示
# ，
# 現年
# 31
# 歲
# 的
# 菲爾普斯
# ，
# 是
# 奧運
# 游泳
# 史上
# 最
# 老
# 的
# 個
# 人
# 金牌得主
# 。

# %%
#encoding=utf-8
#Regular expression 再做斷詞
import jieba
import re
import string  

content = open('test.txt', 'rb').read()

temp = content.decode("utf8")  
string = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）「」]+".decode("utf8"), "".decode("utf8"),temp)  
print string  

#print "Input：", line

words = jieba.cut(string, cut_all=False)

print "Output 精確模式 Full Mode："
for word in words:
    print word
# Out:
# 里約奧運男子200公尺蝶式美國飛魚菲爾普斯MichaelPhelps以1分53秒36的成績獲勝奪下奧運生涯第20金同時締造許多難以超越的飛魚障礙據ESPN顯示現年31歲的菲爾普斯是奧運游泳史上最老的個人金牌得主
# Output 精確模式 Full Mode：
# 里
# 約
# 奧運
# 男子
# 200
# 公尺
# 蝶式
# 美國飛
# 魚菲爾普斯
# MichaelPhelps
# 以
# 1
# 分
# 53
# 秒
# 36
# 的
# 成績
# 獲勝奪
# 下
# 奧運
# 生涯
# 第
# 20
# 金同時
# 締造
# 許多
# 難以
# 超越
# 的
# 飛魚
# 障礙
# 據
# ESPN
# 顯示
# 現年
# 31
# 歲
# 的
# 菲爾普斯
# 是
# 奧運
# 游泳
# 史上
# 最
# 老
# 的
# 個
# 人
# 金牌得主

# %%
#encoding=utf-8
#Regular expression 再做斷詞
#多加 Dictionary
import jieba
import re
import string  

content = open('test.txt', 'rb').read()

temp = content.decode("utf8")  
string = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）「」]+".decode("utf8"), "".decode("utf8"),temp)  
print string  

#print "Input：", line
jieba.set_dictionary('dict2.txt.big')
words = jieba.cut(string, cut_all=False)

print "Output 精確模式 Full Mode："
for word in words:
    print word
# Out:
# Building prefix dict from /root/dict2.txt.big ...
# Loading model from cache /tmp/jieba.u9d93b4ecce4c0df56bca23882edd0f1c.cache
# 里約奧運男子200公尺蝶式美國飛魚菲爾普斯MichaelPhelps以1分53秒36的成績獲勝奪下奧運生涯第20金同時締造許多難以超越的飛魚障礙據ESPN顯示現年31歲的菲爾普斯是奧運游泳史上最老的個人金牌得主
# Output 精確模式 Full Mode：
# Loading model cost 0.987 seconds.
# Prefix dict has been built succesfully.
# 里
# 約
# 奧運
# 男子
# 200
# 公尺
# 蝶式
# 美國
# 飛魚
# 菲爾
# 普斯
# MichaelPhelps
# 以
# 1
# 分
# 53
# 秒
# 36
# 的
# 成績
# 獲勝
# 奪下
# 奧運
# 生涯
# 第
# 20
# 金
# 同時
# 締造
# 許多
# 難以
# 超越
# 的
# 飛魚
# 障礙
# 據
# ESPN
# 顯示
# 現年
# 31
# 歲
# 的
# 菲爾
# 普斯是
# 奧運
# 游泳
# 史上
# 最
# 老
# 的
# 個人
# 金牌得主

# %%
#encoding=utf-8
import jieba
import re
import string  

content = open('test.txt', 'rb').read()

temp = content.decode("utf8")  
string = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）「」]+".decode("utf8"), "".decode("utf8"),temp)  
print string  

#print "Input：", line

words = jieba.cut(string, cut_all=False)

print "Output 精確模式 Full Mode："


di = {}
for word in words:
    di[word] = di.get(word,0)+1

sorted_di = sorted(di.items(),key = lambda e:e[1],reverse = True )
#印出排序字詞
print(sorted_di)

f = open('test1.txt', 'w') 



for key,value in sorted_di:
    #如果有發現數字，便不寫入
    if re.search('\d',key) != None:
        pass
    #其餘文字資料則寫入記事本
    else:
        f.write(key.encode('utf8') +' '+str(value)+'\n')
f.close()
# Out:
# 里約奧運男子200公尺蝶式美國飛魚菲爾普斯MichaelPhelps以1分53秒36的成績獲勝奪下奧運生涯第20金同時締造許多難以超越的飛魚障礙據ESPN顯示現年31歲的菲爾普斯是奧運游泳史上最老的個人金牌得主
# Output 精確模式 Full Mode：
# ...

# %%
import httplib, urllib

params = urllib.urlencode({'q': '*.*', 'df': 'content', 'fl': 'article_title,content,board','rows':'10'})
headers = {"Content-type": "application/x-www-form-urlencoded", "Accept": "text/plain"}
conn = httplib.HTTPConnection("http://127.0.0.1:8983")

conn.request("POST", "/solr/new_core/query", params, headers)
r1 = conn.getresponse()
print r1.responseHeader, r1.status
data1 = r1.read()
print data1
conn.close()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# <ipython-input-171-c466744e8a68> in <module>()
#       5 conn = httplib.HTTPConnection("http://127.0.0.1:8983")
#       6
# ----> 7 conn.request("POST", "/solr/new_core/query", params, headers)
#       8 r1 = conn.getresponse()
#       9 print r1.responseHeader, r1.status
#
# /usr/local/python/lib/python2.7/httplib.pyc in request(self, method, url, body, headers)
#     993     def request(self, method, url, body=None, headers={}):
#     994         """Send a complete request to the server."""
# --> 995         self._send_request(method, url, body, headers)
#     996
#     997     def _set_content_length(self, body):
#
# /usr/local/python/lib/python2.7/httplib.pyc in _send_request(self, method, url, body, headers)
#    1027         for hdr, value in headers.iteritems():
#    1028             self.putheader(hdr, value)
# ...

# %%
#encoding=utf-8
import json
import codecs
import jieba
import re
import string
import string
    
f = codecs.open('/root/movie_test_10.json', 'r')
data =json.load(f)
data_1 = data['response']
data_2 = data_1['docs']


a = []
x = 0
while x < 10 :
    b = data_2[x]['content']
    b = b[0]
#    b = b[0]
#    c = c + b
    a.append(b)
    x = x+1
    
#print a[0]
#print c
c = a[0]

#encoding=utf-8
#Regular expression 再做斷詞
#多加 Dictionary


#content = open('test.txt', 'rb').read()

temp = content.decode("utf8")  
string = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）「」:?《》]+".decode("utf8"), "".decode("utf8"), c)  
print string  

#print "Input：", line
jieba.set_dictionary('dict2.txt.big')
words = jieba.cut(string, cut_all=False)

print "Output 精確模式 Full Mode："
for word in words:
    print word
    
di = {}
for word in words:
    di[word] = di.get(word,0)+1

sorted_di = sorted(di.items(),key = lambda e:e[1],reverse = True )
#印出排序字詞
print(sorted_di)

f = open('test1.txt', 'w') 



for key,value in sorted_di:
    #如果有發現數字，便不寫入
    if re.search('\d',key) != None:
        pass
    #其餘文字資料則寫入記事本
    else:
        f.write(key.encode('utf8') +' '+str(value)+'\n')
f.close()
# Out:
# Building prefix dict from /root/dict2.txt.big ...
# Loading model from cache /tmp/jieba.u9d93b4ecce4c0df56bca23882edd0f1c.cache
# 1請描述欲尋找電影的類型或特徵請盡量描述清楚電影最後一個鏡頭讓人印象深刻會讓人想到這部電影就會想到這一幕希望大家一起分享讓你最念念不忘的結尾鏡頭像是全面啟動裡不斷旋轉的陀螺400擊裡男孩無望的眼神或是太陽照常升起裡第二段結尾在大樓裡上吊的黃秋生都透過一個簡單的鏡頭留給觀眾想像2已知符合需求的電影或偏好的電影類型為避免重複推文請至少列舉一部控制400擊畢業生全面啟動2001太空漫遊幻想戀愛3不喜歡的電影類型不需要板友推薦的電影可填刺陵我的少女時代
# Output 精確模式 Full Mode：
# Loading model cost 0.703 seconds.
# Prefix dict has been built succesfully.
# 1
# 請
# 描述
# 欲
# 尋找
# 電影
# 的
# 類型
# 或
# 特徵
# 請
# 盡量
# 描述
# 清楚
# 電影
# 最後
# 一個
# 鏡頭
# 讓
# 人
# 印象
# 深刻
# 會
# 讓
# 人
# 想到
# 這部
# 電影
# 就
# 會
# 想到
# 這
# 一幕
# 希望
# 大家
# 一起
# 分享
# 讓
# 你
# 最
# 念念不忘
# 的
# 結尾
# 鏡頭
# 像是
# 全面
# 啟動裡
# 不斷
# 旋轉
# 的
# 陀螺
# 400
# 擊裡
# 男孩
# 無望
# 的
# 眼神
# 或是
# 太陽
# 照常
# 升起
# 裡
# 第二段
# 結尾
# 在
# 大樓
# 裡
# 上吊
# 的
# 黃秋生
# 都
# 透過
# 一個
# 簡單
# 的
# 鏡頭
# 留給
# 觀眾
# 想像
# 2
# 已知
# 符合
# 需求
# 的
# 電影
# 或
# 偏好
# 的
# 電影
# 類型
# 為
# 避免
# 重複
# 推文請
# 至少
# 列舉
# 一部
# 控制
# 400
# 擊
# 畢業生
# 全面
# 啟動
# 2001
# 太空
# 漫遊
# 幻想
# 戀愛
# 3
# 不
# 喜歡
# 的
# ...

# %%
#encoding=utf-8
import json
import codecs
import jieba
import re
import string
import string
    
f = codecs.open('/root/movie_test_10.json', 'r')
data =json.load(f)
data_1 = data['response']
data_2 = data_1['docs']


a = []
x = 0
while x < 10 :
    b = data_2[x]['content']
    b = b[0]
#    b = b[0]
#    c = c + b
    a.append(b)
    
    
    #print a[0]
    #print c
    c = a[0]

    #encoding=utf-8
    #Regular expression 再做斷詞
    #多加 Dictionary


    #content = open('test.txt', 'rb').read()

    temp = content.decode("utf8")  
    string = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）「」:?《》]+".decode("utf8"), "".decode("utf8"), c)  
    print string  

    #print "Input：", line
    jieba.set_dictionary('dict2.txt.big')
    words = jieba.cut(string, cut_all=False)

    print "Output 精確模式 Full Mode："

    f = open('x', 'w') 

    for word in words:
        print word
        f.write(word.encode('utf8') +' ')
    
    f.close()
    x = x+1
# Out:
# Building prefix dict from /root/dict2.txt.big ...
# Loading model from cache /tmp/jieba.u9d93b4ecce4c0df56bca23882edd0f1c.cache
# 1請描述欲尋找電影的類型或特徵請盡量描述清楚電影最後一個鏡頭讓人印象深刻會讓人想到這部電影就會想到這一幕希望大家一起分享讓你最念念不忘的結尾鏡頭像是全面啟動裡不斷旋轉的陀螺400擊裡男孩無望的眼神或是太陽照常升起裡第二段結尾在大樓裡上吊的黃秋生都透過一個簡單的鏡頭留給觀眾想像2已知符合需求的電影或偏好的電影類型為避免重複推文請至少列舉一部控制400擊畢業生全面啟動2001太空漫遊幻想戀愛3不喜歡的電影類型不需要板友推薦的電影可填刺陵我的少女時代
# Output 精確模式 Full Mode：
# Loading model cost 0.831 seconds.
# Prefix dict has been built succesfully.
# Building prefix dict from /root/dict2.txt.big ...
# Loading model from cache /tmp/jieba.u9d93b4ecce4c0df56bca23882edd0f1c.cache
# 1
# 請
# 描述
# 欲
# 尋找
# 電影
# 的
# 類型
# 或
# 特徵
# 請
# 盡量
# 描述
# 清楚
# 電影
# 最後
# 一個
# 鏡頭
# 讓
# 人
# 印象
# 深刻
# 會
# 讓
# 人
# 想到
# 這部
# 電影
# 就
# 會
# 想到
# 這
# 一幕
# 希望
# 大家
# 一起
# 分享
# 讓
# 你
# 最
# 念念不忘
# 的
# 結尾
# 鏡頭
# 像是
# 全面
# 啟動裡
# 不斷
# 旋轉
# 的
# 陀螺
# 400
# 擊裡
# 男孩
# 無望
# 的
# 眼神
# 或是
# 太陽
# 照常
# 升起
# 裡
# 第二段
# 結尾
# 在
# 大樓
# 裡
# 上吊
# 的
# 黃秋生
# 都
# 透過
# 一個
# 簡單
# 的
# 鏡頭
# 留給
# 觀眾
# 想像
# 2
# 已知
# 符合
# 需求
# 的
# 電影
# 或
# ...

# %%
#encoding=utf-8
import json
import codecs
import jieba
import re
import string
import string
    
f = codecs.open('/root/movie_test_10.json', 'r')
data =json.load(f)
data_1 = data['response']
data_2 = data_1['docs']


a = []
x = 0
while x < 10 :
    b = data_2[x]['content']
    b = b[0]
    a.append(b)
    c = a[x]
    temp = content.decode("utf8")  
    string = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）「」:?《》]+".decode("utf8"), "".decode("utf8"), c)  
    print string  
    jieba.set_dictionary('dict2.txt.big')
    words = jieba.cut(string, cut_all=False)
    print "Output 精確模式 Full Mode："
    f = open(str(x)+'.txt', 'w') 
    for word in words:
        print word
        f.write(word.encode('utf8') +' ')  
    f.close()
    x = x+1
# Out:
# Building prefix dict from /root/dict2.txt.big ...
# Loading model from cache /tmp/jieba.u9d93b4ecce4c0df56bca23882edd0f1c.cache
# 1請描述欲尋找電影的類型或特徵請盡量描述清楚電影最後一個鏡頭讓人印象深刻會讓人想到這部電影就會想到這一幕希望大家一起分享讓你最念念不忘的結尾鏡頭像是全面啟動裡不斷旋轉的陀螺400擊裡男孩無望的眼神或是太陽照常升起裡第二段結尾在大樓裡上吊的黃秋生都透過一個簡單的鏡頭留給觀眾想像2已知符合需求的電影或偏好的電影類型為避免重複推文請至少列舉一部控制400擊畢業生全面啟動2001太空漫遊幻想戀愛3不喜歡的電影類型不需要板友推薦的電影可填刺陵我的少女時代
# Output 精確模式 Full Mode：
# Loading model cost 0.818 seconds.
# Prefix dict has been built succesfully.
# Building prefix dict from /root/dict2.txt.big ...
# Loading model from cache /tmp/jieba.u9d93b4ecce4c0df56bca23882edd0f1c.cache
# 1
# 請
# 描述
# 欲
# 尋找
# 電影
# 的
# 類型
# 或
# 特徵
# 請
# 盡量
# 描述
# 清楚
# 電影
# 最後
# 一個
# 鏡頭
# 讓
# 人
# 印象
# 深刻
# 會
# 讓
# 人
# 想到
# 這部
# 電影
# 就
# 會
# 想到
# 這
# 一幕
# 希望
# 大家
# 一起
# 分享
# 讓
# 你
# 最
# 念念不忘
# 的
# 結尾
# 鏡頭
# 像是
# 全面
# 啟動裡
# 不斷
# 旋轉
# 的
# 陀螺
# 400
# 擊裡
# 男孩
# 無望
# 的
# 眼神
# 或是
# 太陽
# 照常
# 升起
# 裡
# 第二段
# 結尾
# 在
# 大樓
# 裡
# 上吊
# 的
# 黃秋生
# 都
# 透過
# 一個
# 簡單
# 的
# 鏡頭
# 留給
# 觀眾
# 想像
# 2
# 已知
# 符合
# 需求
# 的
# 電影
# 或
# ...
