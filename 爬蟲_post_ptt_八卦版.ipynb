# %%
import requests
from bs4 import BeautifulSoup
import html5lib
import csv
import codecs
import tablib
import uniout

# %%
r = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html')

# %%
r.text
# Out:
# u'<!DOCTYPE html>\n<html>\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t\n\n<meta name="viewport" content="width=device-width, initial-scale=1">\n\n<title>\u6279\u8e22\u8e22\u5be6\u696d\u574a</title>\n\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-common.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-base.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-custom.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/pushstream.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-print.css" media="print">\n\n\n<script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>\n<script src="//images.ptt.cc/v2.17/bbs.js"></script>\n\n\n\t\t\n\n<script type="text/javascript">\n\n  var _gaq = _gaq || [];\n  _gaq.push([\'_setAccount\', \'UA-32365737-1\']);\n  _gaq.push([\'_setDomainName\', \'ptt.cc\']);\n  _gaq.push([\'_t
# ...

# %%
soup = BeautifulSoup(r.text,"html5lib")

# %%
print soup
# Out:
# <!DOCTYPE html>
# <html><head>
# 		<meta charset="utf-8"/>
#
#
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
#
# <title>批踢踢實業坊</title>
#
# <link href="//images.ptt.cc/v2.17/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.17/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
#   _gaq.push(['_trackPageview']);
#
# ...

# %%
payload = {'from':'/bbs/Gossiping/index.html',
          'yes':'yes'}

# %%
requests.packages.urllib3.disable_warnings()

# %%
rs = requests.session()

# %%
res = rs.post('https://www.ptt.cc/ask/over18', verify=False, data=payload)

# %%
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify=False)

# %%
soup = BeautifulSoup(res.text,"html5lib")

# %%
print soup
# Out:
# <!DOCTYPE html>
# <html><head>
# 		<meta charset="utf-8"/>
#
#
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link href="//images.ptt.cc/v2.17/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.17/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
# ...

# %%
D1 = []
for line in soup.select('.r-ent'): 
    A = line.select('.date')[0].text.encode('utf-8'),line.select('.author')[0].text.encode('utf-8'),line.select('.title')[0].text.encode('utf-8')
    D1.append(A)

# %%
print str(D1).decode('string_escape')
# Out:
# [(' 7/22', 'superkobe', '
#
# 				Re: [問卦] 陳進興那時候台北有多恐怖?
#
# 			'), (' 7/22', 'pili', '
#
# 				[新聞] 女兒被美軍收養 52年後想見她
#
# 			'), (' 7/22', 'area41gold', '
#
# 				[新聞] 超萌正妹長大了　網友驚喊「好像子瑜！」
#
# 			'), (' 7/22', 'a0921387223', '
#
# 				[問卦] line瘋傳的火燒車焦屍照片是怎麼來的
#
# 			'), (' 7/22', 'RIFF', '
#
# 				[問卦] 日本女心機重 但女演員獲國際大獎不特多
#
# 			'), (' 7/22', 'joug', '
#
# 				[新聞] 結合3D列印 大葉推碳纖電動車架
#
# 			'), (' 7/22', 'older', '
#
# 				Re: [問卦] 有沒日本17歲女子高中生水泥埋屍案的卦？
#
# 			'), (' 7/22', 'hihier', '
#
# 				Re: [問卦] 矯正牙齒怎麼大家都受的了?
#
# 			'), (' 7/22', 'bota', '
#
# 				[問卦] 假設妹妹從外面抱個小孩回來?
#
# 			'), (' 7/22', 'ilikeilike', '
#
# 				[問卦] 有沒有林鳳營廣告配樂的八卦
#
# 			'), (' 7/22', 'NishinoKana', '
#
# 				[新聞] 《航運股》油價持穩＋擴航班，長榮航獲外
#
# 			'), (' 7/22', 'gary27', '
#
# 				Re: [新聞] 65萬字黨產條例萬言書  林德福：一定要讀
#
# 			'), (' 7/22', 'a111111zz', '
#
# 				[新聞] 人氣美女伊伊看奧運　最支持許淑淨
#
# 			'), (' 7/22', 'skn60694', '
#
# 				[新聞] 地球成大火爐　聯合國提議：縮短工時救暖
#
# 			'), (' 7/22', 'jim66356', '
#
# 				[問卦] 家用室內電話
#
# ...

# %%
dic = {}
for line in soup.select('.r-ent'): 
    A = line.select('.date')[0].text.encode('utf-8')
    B = line.select('.author')[0].text.encode('utf-8')
    C = line.select('.title')[0].text.encode('utf-8')
    print C
    dic['A'] = A
    dic['B'] = B
    dic['C'] = C
    print dic['C']
    print dic

    fid = open('test.txt', 'a') 
    fid.write(A)
    fid.write(B)
    fid.write(C)
    fid.close()
# Out:
#
# 				Re: [問卦] 陳進興那時候台北有多恐怖?
#
#
#
#
# 				Re: [問卦] 陳進興那時候台北有多恐怖?
#
#
# {'A': ' 7/22', 'C': '\n\t\t\t\n\t\t\t\tRe: [\xe5\x95\x8f\xe5\x8d\xa6] \xe9\x99\xb3\xe9\x80\xb2\xe8\x88\x88\xe9\x82\xa3\xe6\x99\x82\xe5\x80\x99\xe5\x8f\xb0\xe5\x8c\x97\xe6\x9c\x89\xe5\xa4\x9a\xe6\x81\x90\xe6\x80\x96?\n\t\t\t\n\t\t\t', 'B': 'superkobe'}
#
#
# 				[新聞] 女兒被美軍收養 52年後想見她
#
#
#
#
# 				[新聞] 女兒被美軍收養 52年後想見她
#
#
# {'A': ' 7/22', 'C': '\n\t\t\t\n\t\t\t\t[\xe6\x96\xb0\xe8\x81\x9e] \xe5\xa5\xb3\xe5\x85\x92\xe8\xa2\xab\xe7\xbe\x8e\xe8\xbb\x8d\xe6\x94\xb6\xe9\xa4\x8a 52\xe5\xb9\xb4\xe5\xbe\x8c\xe6\x83\xb3\xe8\xa6\x8b\xe5\xa5\xb9\n\t\t\t\n\t\t\t', 'B': 'pili'}
#
#
# 				[新聞] 超萌正妹長大了　網友驚喊「好像子瑜！」
#
#
#
#
# 				[新聞] 超萌正妹長大了　網友驚喊「好像子瑜！」
#
#
# ...
