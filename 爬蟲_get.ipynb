# %%
import requests
from bs4 import BeautifulSoup
#import lxml
import html5lib

# %%
r = requests.get('https://www.ptt.cc/bbs/NBA/index.html')

# %%
r.text
# Out:
# u'<!DOCTYPE html>\n<html>\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t\n\n<meta name="viewport" content="width=device-width, initial-scale=1">\n\n<title>\u770b\u677f NBA \u6587\u7ae0\u5217\u8868 - \u6279\u8e22\u8e22\u5be6\u696d\u574a</title>\n\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-common.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-base.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-custom.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/pushstream.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.17/bbs-print.css" media="print">\n\n\n<script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>\n<script src="//images.ptt.cc/v2.17/bbs.js"></script>\n\n\n\t\t\n\n<script type="text/javascript">\n\n  var _gaq = _gaq || [];\n  _gaq.push([\'_setAccount\', \'UA-32365737-1\']);\n  _gaq.push([\'_setDomainName\', \'ptt.cc\']);\n  _gaq.push([\'_trackPageview\']);\n\n  (function() {\n    var ga = document.createElement(\'script\'); ga.type = \'text/javascript\'; ga.async = true;\n    ga.src = (\'https:\' == document.location.protocol ? \'https://ssl\' : \'http://www\') + \'.google-analytics.com/ga.js\';\n    var s = document.getElementsByTagName(\'script\')[0]; s.parentNode.insertBefore(ga, s);\n  })();\n\n</script>\n\n\n\t</head>\n    <body>\n\t\t\n<div id="topbar-container">\n\t<div id="topbar" class="bbs-content">\n\t\t<a id="logo" href="/">\u6279\u8e22\u8e22\u5be6\u696d\u574a</a>\n\t\t<span>&rsaquo;</span>\n\t\t<a class="board" href="/bbs/NBA/index.html"><span class="board-label">\u770b\u677f </span>NBA</a>\n\t\t<a class="right small" href="/about.html">\u95dc\u65bc\u6211\u5011</a>\n\t\t<a class="right small" href="/contact.html">\u806f\u7d61\u8cc7\u8a0a</a>\n\t</div>\n</div>\n\n<div id="main-container">\n\t<div id="action-bar-container">\n\t\t<div class="action-bar">\n\t\t\t<div class="btn-group btn-group-dir">\n\t\t\t\t<a class="btn selected" href="/bbs/NBA/index.html">\u770b\u677f</a>\n\t\t\t\t<a class="btn" href="/man/NBA/index.html">\u7cbe\u83ef\u5340</a>\n\t\t\t</div>\n\t\t\t<div class="btn-group btn-group-paging">\n\t\t\t\t<a class="btn wide" href="/bbs/NBA/index1.html">\u6700\u820a</a>\n\t\t\t\t<a class="btn wide" href="/bbs/NBA/index4027.html">&lsaquo; \u4e0a\u9801</a>\n\t\t\t\t<a class="btn wide disabled">\u4e0b\u9801 &rsaquo;</a>\n\t\t\t\t<a class="btn wide" href="/bbs/NBA/index.html">\u6700\u65b0</a>\n\t\t\t</div>\n\t\t</div>\n\t</div>\n\n\t<div class="r-list-container bbs-screen">\n\t\t\n\t\t\n            \n        \n        \n\t\t<div class="r-ent">\n\t\t\t<div class="nrec"><span class="hl f3">24</span></div>\n\t\t\t<div class="mark"></div>\n\t\t\t<div class="title">\n\t\t\t\n\t\t\t\t<a href="/bbs/NBA/M.1468989479.A.36B.html">[\u65b0\u805e] \u65b0\u5b63\u5148\u767c\u63a7\u885b\u627e\u5230\u7b54\u6848 \u7c43\u7db2\u8ff7\u611f\u8b1d\u6797\u66f8\u8c6a</a>\n\t\t\t\n\t\t\t</div>\n\t\t\t<div class="meta">\n\t\t\t\t<div class="date"> 7/20</div>\n\t\t\t\t<div class="author">ztopip</div>\n\t\t\t</div>\n\t\t</div>\n\n\t\t\n            \n        \n        \n\t\t<div class="r-ent">\n\t\t\t<div class="nrec"></div>\n\t\t\t<div class="mark"></div>\n\t\t\t<div class="title">\n\t\t\t\n\t\t\t\t(\u672c\u6587\u5df2\u88ab\u522a\u9664) [CAF0612]\n\t\t\t\n\t\t\t</div>\n\t\t\t<div class="meta">\n\t\t\t\t<div class="date"> 7/20</div>\n\t\t\t\t<div class="author">-</div>\n\t\t\t</div>\n\t\t</div>\n\n\t\t\n            \n        \n        \n\t\t<div class="r-ent">\n\t\t\t<div class="nrec"><span class="hl f3">76</span></div>\n\t\t\t<div class="mark"></div>\n\t\t\t<div class="title">\n\t\t\t\n\t\t\t\t<a href="/bbs/NBA/M.1468991106.A.71D.html">[\u65b0\u805e] \u7f8e\u570b\u5967\u904b\u7537\u7c43\u958b\u8a13 \u661f\u5149\u9eef\u6de1\u88ab\u9178\u4e8c\u8ecd</a>\n\t\t\t\n\t\t\t</div>\n\t\t\t<div class="meta">\n\t\t\t\t<div class="date"> 7/20</div>\n\t\t\t\t<div cl ...

# %%
soup = BeautifulSoup(r.text,"html5lib")

# %%
print soup
# Out:
# <!DOCTYPE html>
# <html><head>
# 		<meta charset="utf-8"/>
#
#
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
#
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
#
# <link href="//images.ptt.cc/v2.17/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/v2.17/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.17/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div class="bbs-content" id="topbar">
# 		<a href="/" id="logo">批踢踢實業坊</a>
# 		<span>›</span>
# 		<a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/NBA/index.html">看板</a>
# 				<a class="btn" href="/man/NBA/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/NBA/index4027.html">‹ 上頁</a>
# 				<a class="btn wide disabled">下頁 ›</a>
# 				<a class="btn wide" href="/bbs/NBA/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container bbs-screen">
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">24</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1468989479.A.36B.html">[新聞] 新季先發控衛找到答案 籃網迷感謝林書豪</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">ztopip</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				(本文已被刪除) [CAF0612]
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">-</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">76</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1468991106.A.71D.html">[新聞] 美國奧運男籃開訓 星光黯淡被酸二軍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">vm04vm04</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1468992625.A.7C5.html">[專欄] 我的新秀賽季 - 姚明</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">cody7052</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">21</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1468994055.A.247.html">[新聞] 以詹皇為師 美夢對隊主控厄文學會當領袖LYS</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">colin4235tw</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">86</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1469000209.A.693.html">[討論] 為什麼魔獸無法成為第一中鋒??</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">smarco</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">63</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1469001950.A.1BE.html">[新聞] 關鍵拼圖陸續到位! 安東尼：恐怖尼克要</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">US300</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">60</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1469003716.A.637.html">[新聞] NBA／國王考辛斯：看不懂球團的選秀策略</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">USAGI0423</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">21</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1469006986.A.A92.html">[情報] NBA本屆里約奧運參賽選手</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">RVDmania</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">17</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1469008958.A.E94.html">[討論] 近三年年度第一隊比較</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">dro001</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1469009813.A.C52.html">[新聞] 杜蘭特談湖人榜眼新秀 「像鏡中的我」</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">thnlkj0665</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">13</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1469011846.A.404.html">[情報] 歷年NBA冠軍隊伍 隊中年度陣容球員數</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">twopiece</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">7</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1469012649.A.349.html">[新聞] 正式簽約公牛 韋德：回家感覺真好</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/20</div>
# 				<div class="author">taiwan71924</div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="mark">!</div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1467211360.A.AFD.html">[公告] 板規6.0</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/29</div>
# 				<div class="author">Hijikata</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1466758463.A.2D9.html">[情報] 2016-17 球員異動整理表 (包含新秀,教頭)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 6/24</div>
# 				<div class="author">laigei</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">88</span></div>
# 			<div class="mark">M</div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1467385009.A.200.html">[情報] 2016-17 球員異動整理表 (逐日文字版)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/01</div>
# 				<div class="author">laigei</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1468833886.A.7C8.html">[情報] 2016-17 新秀 60順位簽約進度</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/18</div>
# 				<div class="author">laigei</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">29</span></div>
# 			<div class="mark"></div>
# 			<div class="title">
#
# 				<a href="/bbs/NBA/M.1468666850.A.250.html">[情報] USA Basketball Schedule</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="date"> 7/16</div>
# 				<div class="author">LakersMamba</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#
#
# </body></html>

# %%
soup.html.head.title
# Out:
# <title>\u770b\u677f NBA \u6587\u7ae0\u5217\u8868 - \u6279\u8e22\u8e22\u5be6\u696d\u574a</title>

# %%
print soup.a
# Out:
# <a href="/" id="logo">批踢踢實業坊</a>

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /bbs/NBA/index.html
# /about.html
# /contact.html
# /bbs/NBA/index.html
# /man/NBA/index.html
# /bbs/NBA/index1.html
# /bbs/NBA/index4027.html
# None
# /bbs/NBA/index.html
# /bbs/NBA/M.1468989479.A.36B.html
# /bbs/NBA/M.1468991106.A.71D.html
# /bbs/NBA/M.1468992625.A.7C5.html
# /bbs/NBA/M.1468994055.A.247.html
# /bbs/NBA/M.1469000209.A.693.html
# /bbs/NBA/M.1469001950.A.1BE.html
# /bbs/NBA/M.1469003716.A.637.html
# /bbs/NBA/M.1469006986.A.A92.html
# /bbs/NBA/M.1469008958.A.E94.html
# /bbs/NBA/M.1469009813.A.C52.html
# /bbs/NBA/M.1469011846.A.404.html
# /bbs/NBA/M.1467211360.A.AFD.html
# /bbs/NBA/M.1466758463.A.2D9.html
# /bbs/NBA/M.1467385009.A.200.html
# /bbs/NBA/M.1468833886.A.7C8.html
# /bbs/NBA/M.1468666850.A.250.html

# %%
for line in soup.select('.r-ent'):
    print line.select('.title')[0].text.encode('utf-8')
    print line.select('.date')[0].text.encode('utf-8'),line.select('.author')[0].text.encode('utf-8')
# Out:
#
# 				[新聞] 新季先發控衛找到答案 籃網迷感謝林書豪
#
#
#  7/20 ztopip
#
#
# 				(本文已被刪除) [CAF0612]
#
#
#  7/20 -
#
#
# 				[新聞] 美國奧運男籃開訓 星光黯淡被酸二軍
#
#
#  7/20 vm04vm04
#
#
# 				[專欄] 我的新秀賽季 - 姚明
#
#
#  7/20 cody7052
#
#
# 				[新聞] 以詹皇為師 美夢對隊主控厄文學會當領袖LYS
#
#
#  7/20 colin4235tw
#
#
# 				[討論] 為什麼魔獸無法成為第一中鋒??
#
#
#  7/20 smarco
#
#
# 				[新聞] 關鍵拼圖陸續到位! 安東尼：恐怖尼克要
#
#
#  7/20 US300
#
#
# 				[新聞] NBA／國王考辛斯：看不懂球團的選秀策略
#
#
#  7/20 USAGI0423
#
#
# 				[情報] NBA本屆里約奧運參賽選手
#
#
#  7/20 RVDmania
#
#
# 				[討論] 近三年年度第一隊比較
#
#
#  7/20 dro001
#
#
# 				[新聞] 杜蘭特談湖人榜眼新秀 「像鏡中的我」
#
#
#  7/20 thnlkj0665
#
#
# 				[情報] 歷年NBA冠軍隊伍 隊中年度陣容球員數
#
#
#  7/20 twopiece
#
#
# 				[公告] 板規6.0
#
#
#  6/29 Hijikata
#
#
# 				[情報] 2016-17 球員異動整理表 (包含新秀,教頭)
#
#
#  6/24 laigei
#
#
# 				[情報] 2016-17 球員異動整理表 (逐日文字版)
#
#
#  7/01 laigei
#
#
# 				[情報] 2016-17 新秀 60順位簽約進度
#
#
#  7/18 laigei
#
#
# 				[情報] USA Basketball Schedule
#
#
#  7/16 LakersMamba
